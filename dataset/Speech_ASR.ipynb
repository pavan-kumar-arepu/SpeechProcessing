# %%
import torchaudio

dataset = torchaudio.datasets.LIBRISPEECH(
    root="./data",
    url="test-clean",
    download=True
)

print(len(dataset))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torchaudio
#       2
#       3 dataset = torchaudio.datasets.LIBRISPEECH(
#       4     root="./data",
#
# ModuleNotFoundError: No module named 'torchaudio'
