# %% [markdown]
# # HMM-DNN Based Automatic Speech Recognition
#
# ## Speech Processing Assignment
#
# ### STEP 1 - Objective
#
# This project implements a Hybrid Automatic Speech Recognition (ASR) system using Deep Neural Networks combined with Hidden Markov Models.
#
# The system pipeline includes:
#
# - Speech preprocessing
# - MFCC and Log-Mel feature extraction
# - Deep Neural Network based acoustic modeling
# - HMM based sequence modeling
# - Viterbi decoding
# - Word Error Rate evaluation
#
#
# Dataset Used:
#
# LibriSpeech ASR Corpus (test-clean subset)

# %%
## STEP2 - Import Required Libraries

# Core libraries

import os
import numpy as np
import matplotlib.pyplot as plt


# Deep Learning

import torch
import torch.nn as nn
import torchaudio


# Audio processing

import torchaudio.transforms as T


print("Torch Version:", torch.__version__)
print("TorchAudio Version:", torchaudio.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 7
#       3 # Core libraries
#       4
#       5 import os
#       6 import numpy as np
# ----> 7 import matplotlib.pyplot as plt
#       8
#       9
#      10 # Deep Learning
#
# File ~/BitsPilani/2nd Year/AIMLCZG520_SpeechProcessing/Assignment/Solution/SpeechProcessing/.venv/lib/python3.11/site-packages/matplotlib/__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
#     160 # definitions, so it is safe to import from it here.
# --> 161 from . import _api, _version, cbook, rcsetup
#     162 from matplotlib._api import MatplotlibDeprecationWarning
#     163 from matplotlib.colors import _color_sequences as color_sequences
#
# File ~/BitsPilani/2nd Year/AIMLCZG520_SpeechProcessing/Assignment/Solution/SpeechProcessing/.venv/lib/python3.11/site-packages/matplotlib/rcsetup.py:2148
#    1505     description: str = None
#    1508 # Definition of all rcParams. This is currently only used to generate the documentation.
#    1509 #
#    1510 # Actual runtime values do still come from the historic sources:
#    (...)   1519 #
#    1520 # In the transition phase, consistency is ensured via tests.
#    1521 _DEFINITION = [
#    1522     _Section("Backends"),
#    1523     _Param(
#    1524         "webagg.port",
#    1525         default=8988,
#    1526         validator=validate_int,
#    1527         description="The port to use for the web server in the WebAgg backend."
#    1528     ),
#    1529     _Param(
#    1530         "webagg.address",
#    1531         default="127.0.0.1",
#    1532         validator=validate_string,
#    1533         description="The address on which the WebAgg web server should be reachable."
#    1534     ),
#    1535     _Param(
#    1536         "webagg.port_retries",
#    1537         default=50,
#    1538         validator=validate_int,
#    1539         description="If webagg.port is unavailable, a number of other random ports "
#    1540                     "will be tried until one that is available is found."
#    1541     ),
#    1542     _Param(
#    1543         "webagg.open_in_browser",
#    1544         default=True,
#    1545         validator=validate_bool,
#    1546         description="When True, open the web browser to the plot that is shown"
#    1547     ),
#    1548     _Param(
#    1549         "backend_fallback",
#    1550         default=True,
#    1551         validator=validate_bool,
#    1552         description="If you are running pyplot inside a GUI and your backend choice "
#    1553                     "conflicts, we will automatically try to find a compatible one for "
#    1554                     "you if backend_fallback is True"
#    1555     ),
#    1556     _Param(
#    1557         "interactive",
#    1558         default=False,
#    1559         validator=validate_bool
#    1560     ),
#    1561     _Param(
#    1562         "figure.hooks",
#    1563         default=[],
#    1564         validator=validate_stringlist,
#    1565         description="list of dotted.module.name:dotted.callable.name"
#    1566     ),
#    1567     _Param(
#    1568         "toolbar",
#    1569         default="toolbar2",
#    1570         validator=_validate_toolbar,
#    1571         description="{None, toolbar2, toolmanager}"
#    1572     ),
#    1573     _Param(
#    1574         "timezone",
#    1575         default="UTC",
#    1576         validator=validate_string,
#    1577         description="a pytz timezone string, e.g., US/Central or Europe/Paris"
#    1578     ),
#    1579     _Section(
#    1580         "Lines",
#    1581         description="Default properties for line objects, such as those returned by "
#    1582                     "plot()."
#    1583     ),
#    1584     _Param(
#    1585         "lines.linewidth",
#    1586         default=1.5,
#    1587         validator=validate_float,
#    1588         description="line width in points"
#    1589     ),
#    1590     _Param(
#    1591         "lines.linestyle",
#    1592         default="-",
#    1593         validator=_validate_linestyle,
#    1594         description="solid line"
#    1595     ),
#    1596     _Param(
#    1597         "lines.color",
#    1598         default="C0",
#    1599         validator=validate_color,
#    1600         description="has no affect on plot(); see axes.prop_cycle"
#    1601     ),
#    1602     _Param(
#    1603         "lines.marker",
#    1604         default="None",
#    1605         validator=_validate_marker,
#    1606         description="the default marker"
#    1607     ),
#    1608     _Param(
#    1609         "lines.markerfacecolor",
#    1610         default="auto",
#    1611         validator=validate_color_or_auto,
#    1612         description="the default marker face color"
#    1613     ),
#    1614     _Param(
#    1615         "lines.markeredgecolor",
#    1616         default="auto",
#    1617         validator=validate_color_or_auto,
#    1618         description="the default marker edge color"
#    1619     ),
#    1620     _Param(
#    1621         "lines.markeredgewidth",
#    1622         default=1.0,
#    1623         validator=validate_float,
#    1624         description="the line width around the marker symbol"
#    1625     ),
#    1626     _Param(
#    1627         "lines.markersize",
#    1628         default=6.0,
#    1629         validator=validate_float,
#    1630         description="marker size, in points"
#    1631     ),
#    1632     _Param(
#    1633         "lines.dash_joinstyle",
#    1634         default="round",
#    1635         validator=JoinStyle,
#    1636         description="{miter, round, bevel}"
#    1637     ),
#    1638     _Param(
#    1639         "lines.dash_capstyle",
#    1640         default="butt",
#    1641         validator=CapStyle,
#    1642         description="{butt, round, projecting}"
#    1643     ),
#    1644     _Param(
#    1645         "lines.solid_joinstyle",
#    1646         default="round",
#    1647         validator=JoinStyle,
#    1648         description="{miter, round, bevel}"
#    1649     ),
#    1650     _Param(
#    1651         "lines.solid_capstyle",
#    1652         default="projecting",
#    1653         validator=CapStyle,
#    1654         description="{butt, round, projecting}"
#    1655     ),
#    1656     _Param(
#    1657         "lines.antialiased",
#    1658         default=True,
#    1659         validator=validate_bool,
#    1660         description="render lines in antialiased (no jaggies)"
#    1661     ),
#    1662     _Param(
#    1663         "lines.dashed_pattern",
#    1664         default=[3.7, 1.6],
#    1665         validator=validate_floatlist,
#    1666         description="The dash pattern for linestyle 'dashed'"
#    1667     ),
#    1668     _Param(
#    1669         "lines.dashdot_pattern",
#    1670         default=[6.4, 1.6, 1.0, 1.6],
#    1671         validator=validate_floatlist,
#    1672         description="The dash pattern for linestyle 'dashdot'"
#    1673     ),
#    1674     _Param(
#    1675         "lines.dotted_pattern",
#    1676         default=[1.0, 1.65],
#    1677         validator=validate_floatlist,
#    1678         description="The dash pattern for linestyle 'dotted'"
#    1679     ),
#    1680     _Param(
#    1681         "lines.scale_dashes",
#    1682         default=True,
#    1683         validator=validate_bool
#    1684     ),
#    1685     _Param(
#    1686         "markers.fillstyle",
#    1687         default="full",
#    1688         validator=validate_fillstyle,
#    1689         description="{full, left, right, bottom, top, none}"
#    1690     ),
#    1691     _Param(
#    1692         "pcolor.shading",
#    1693         default="auto",
#    1694         validator=["auto", "flat", "nearest", "gouraud"]
#    1695     ),
#    1696     _Param(
#    1697         "pcolormesh.snap",
#    1698         default=True,
#    1699         validator=validate_bool,
#    1700         description="Whether to snap the mesh to pixel boundaries. This is provided "
#    1701                     "solely to allow old test images to remain unchanged. Set to False "
#    1702                     "to obtain the previous behavior."
#    1703     ),
#    1704     _Section("Patches"),
#    1705     _Param(
#    1706         "patch.linewidth",
#    1707         default=1.0,
#    1708         validator=validate_float,
#    1709         description="edge width in points."
#    1710     ),
#    1711     _Param(
#    1712         "patch.facecolor",
#    1713         default="C0",
#    1714         validator=validate_color
#    1715     ),
#    1716     _Param(
#    1717         "patch.edgecolor",
#    1718         default="black",
#    1719         validator=validate_color,
#    1720         description='By default, Patches and Collections do not draw edges. This value '
#    1721                     'is only used if facecolor is "none" (an Artist without facecolor '
#    1722                     'and edgecolor would be invisible)  or if patch.force_edgecolor '
#    1723                     'is True.'
#    1724     ),
#    1725     _Param(
#    1726         "patch.force_edgecolor",
#    1727         default=False,
#    1728         validator=validate_bool,
#    1729         description="By default, Patches and Collections do not draw edges. Set this "
#    1730                     "to True to draw edges with patch.edgedcolor as the default "
#    1731                     "edgecolor. This is mainly relevant for styles."
#    1732     ),
#    1733     _Param(
#    1734         "patch.antialiased",
#    1735         default=True,
#    1736         validator=validate_bool,
#    1737         description="render patches in antialiased (no jaggies)"
#    1738     ),
#    1739     _Section("Hatches"),
#    1740     _Param("hatch.color", "edge", _validate_color_or_edge),
#    1741     _Param("hatch.linewidth", 1.0, validate_float),
#    1742     _Section("Boxplot"),
#    1743     _Param("boxplot.notch", False, validate_bool),
#    1744     _Param("boxplot.vertical", True, validate_bool),
#    1745     _Param("boxplot.whiskers", 1.5, validate_whiskers),
#    1746     _Param("boxplot.bootstrap", None, validate_int_or_None),
#    1747     _Param("boxplot.patchartist", False, validate_bool),
#    1748     _Param("boxplot.showmeans", False, validate_bool),
#    1749     _Param("boxplot.showcaps", True, validate_bool),
#    1750     _Param("boxplot.showbox", True, validate_bool),
#    1751     _Param("boxplot.showfliers", True, validate_bool),
#    1752     _Param("boxplot.meanline", False, validate_bool),
#    1753     _Param("boxplot.flierprops.color", "black", validate_color),
#    1754     _Param("boxplot.flierprops.marker", "o", _validate_marker),
#    1755     _Param("boxplot.flierprops.markerfacecolor", "none", validate_color_or_auto),
#    1756     _Param("boxplot.flierprops.markeredgecolor", "black", validate_color),
#    1757     _Param("boxplot.flierprops.markeredgewidth", 1.0, validate_float),
#    1758     _Param("boxplot.flierprops.markersize", 6.0, validate_float),
#    1759     _Param("boxplot.flierprops.linestyle", "none", _validate_linestyle),
#    1760     _Param("boxplot.flierprops.linewidth", 1.0, validate_float),
#    1761     _Param("boxplot.boxprops.color", "black", validate_color),
#    1762     _Param("boxplot.boxprops.linewidth", 1.0, validate_float),
#    1763     _Param("boxplot.boxprops.linestyle", "-", _validate_linestyle),
#    1764     _Param("boxplot.whiskerprops.color", "black", validate_color),
#    1765     _Param("boxplot.whiskerprops.linewidth", 1.0, validate_float),
#    1766     _Param("boxplot.whiskerprops.linestyle", "-", _validate_linestyle),
#    1767     _Param("boxplot.capprops.color", "black", validate_color),
#    1768     _Param("boxplot.capprops.linewidth", 1.0, validate_float),
#    1769     _Param("boxplot.capprops.linestyle", "-", _validate_linestyle),
#    1770     _Param("boxplot.medianprops.color", "C1", validate_color),
#    1771     _Param("boxplot.medianprops.linewidth", 1.0, validate_float),
#    1772     _Param("boxplot.medianprops.linestyle", "-", _validate_linestyle),
#    1773     _Param("boxplot.meanprops.color", "C2", validate_color),
#    1774     _Param("boxplot.meanprops.marker", "^", _validate_marker),
#    1775     _Param("boxplot.meanprops.markerfacecolor", "C2", validate_color),
#    1776     _Param("boxplot.meanprops.markeredgecolor", "C2", validate_color),
#    1777     _Param("boxplot.meanprops.markersize", 6.0, validate_float),
#    1778     _Param("boxplot.meanprops.linestyle", "--", _validate_linestyle),
#    1779     _Param("boxplot.meanprops.linewidth", 1.0, validate_float),
#    1780     _Section(
#    1781         "Font",
#    1782         description="The font properties used by `.Text` "
#    1783                     "See https://matplotlib.org/stable/api/font_manager_api.html for "
#    1784                     "more information on font properties. The 6 font properties used "
#    1785                     "for font matching are given below with their default values."
#    1786     ),
#    1787     _Param("font.family", ["sans-serif"], validate_stringlist),
#    1788     _Param("font.style", "normal", validate_string),
#    1789     _Param("font.variant", "normal", validate_string),
#    1790     _Param("font.weight", "normal", validate_fontweight),
#    1791     _Param("font.stretch", "normal", validate_fontstretch),
#    1792     _Param("font.size", 10.0, validate_float),
#    1793     _Param(
#    1794         "font.serif",
#    1795         default=[
#    1796             "DejaVu Serif", "Bitstream Vera Serif", "Computer Modern Roman",
#    1797             "New Century Schoolbook", "Century Schoolbook L", "Utopia", "ITC Bookman",
#    1798             "Bookman", "Nimbus Roman No9 L", "Times New Roman", "Times", "Palatino",
#    1799             "Charter", "serif",
#    1800         ],
#    1801         validator=validate_stringlist
#    1802     ),
#    1803     _Param(
#    1804         "font.sans-serif",
#    1805         default=[
#    1806             "DejaVu Sans", "Bitstream Vera Sans", "Computer Modern Sans Serif",
#    1807             "Lucida Grande", "Verdana", "Geneva", "Lucid", "Arial", "Helvetica",
#    1808             "Avant Garde", "sans-serif",
#    1809         ],
#    1810         validator=validate_stringlist
#    1811     ),
#    1812     _Param(
#    1813         "font.cursive",
#    1814         default=[
#    1815             "Apple Chancery", "Textile", "Zapf Chancery", "Sand", "Script MT", "Felipa",
#    1816             "Comic Neue", "Comic Sans MS", "cursive",
#    1817         ],
#    1818         validator=validate_stringlist
#    1819     ),
#    1820     _Param(
#    1821         "font.fantasy",
#    1822         default=["Chicago", "Charcoal", "Impact", "Western", "xkcd script", "fantasy"],
#    1823         validator=validate_stringlist
#    1824     ),
#    1825     _Param(
#    1826         "font.monospace",
#    1827         default=[
#    1828             "DejaVu Sans Mono", "Bitstream Vera Sans Mono",
#    1829             "Computer Modern Typewriter", "Andale Mono", "Nimbus Mono L", "Courier New",
#    1830             "Courier", "Fixed", "Terminal", "monospace",
#    1831         ],
#    1832         validator=validate_stringlist
#    1833     ),
#    1834     _Param(
#    1835         "font.enable_last_resort",
#    1836         default=True,
#    1837         validator=validate_bool,
#    1838         description="If True, then Unicode Consortium's Last Resort font will be "
#    1839                     "appended to all font selections. This ensures that there will "
#    1840                     "always be a glyph displayed."
#    1841     ),
#    1842     _Section("Text properties"),
#    1843     _Param(
#    1844         "text.color",
#    1845         default="black",
#    1846         validator=validate_color
#    1847     ),
#    1848     _Param(
#    1849         "text.language",
#    1850         default=None,
#    1851         validator=validate_string_or_None,
#    1852         description="The language of the text in a format accepted by libraqm, namely "
#    1853                     "`a BCP47 language code "
#    1854                     "<https://www.w3.org/International/articles/language-tags/>`_. If "
#    1855                     "None, then no particular language will be implied, and default "
#    1856                     "font settings will be used."
#    1857     ),
#    1858     _Param(
#    1859         "text.hinting",
#    1860         default="default",
#    1861         validator=[
#    1862             "default", "no_autohint", "force_autohint", "no_hinting", "auto", "native",
#    1863             "either", "none",
#    1864         ],
#    1865         description="FreeType hinting flag (\"foo\" corresponds to FT_LOAD_FOO); may "
#    1866                     "be one of the following (Proprietary Matplotlib-specific synonyms "
#    1867                     "are given in parentheses, but their use is discouraged): "
#    1868                     "- default: Use the font's native hinter if possible, else "
#    1869                     "  FreeType's auto-hinter. (\"either\" is a synonym)."
#    1870                     "- no_autohint: Use the font's native hinter if possible, else "
#    1871                     "  don't hint. (\"native\" is a synonym.)"
#    1872                     "- force_autohint: Use FreeType's auto-hinter. (\"auto\" is a "
#    1873                     "  synonym.)"
#    1874                     "- no_hinting: Disable hinting. (\"none\" is a synonym.)"
#    1875     ),
#    1876     _Param(
#    1877         "text.hinting_factor",
#    1878         default=None,
#    1879         validator=validate_int_or_None,
#    1880         description="[DEPRECATED] This setting has no effect."
#    1881     ),
#    1882     _Param(
#    1883         "text.kerning_factor",
#    1884         default=None,
#    1885         validator=validate_int_or_None,
#    1886         description="[DEPRECATED] Specifies the scaling factor for kerning values. "
#    1887                     "This is provided solely to allow old test images to remain "
#    1888                     "unchanged. Set to 6 to obtain previous behavior. Values other "
#    1889                     "than 0 or 6 have no defined meaning."
#    1890     ),
#    1891     _Param(
#    1892         "text.antialiased",
#    1893         default=True,
#    1894         validator=validate_bool,
#    1895         description="If True (default), the text will be antialiased. This only "
#    1896                     "affects raster outputs."
#    1897     ),
#    1898     _Param(
#    1899         "text.parse_math",
#    1900         default=True,
#    1901         validator=validate_bool,
#    1902         description="Use mathtext if there is an even number of unescaped dollar signs."
#    1903
#    1904     ),
#    1905     _Section("Mathtext and LaTeX"),
#    1906     _Param(
#    1907         "text.usetex",
#    1908         default=False,
#    1909         validator=validate_bool,
#    1910         description="use latex for all text handling. The following fonts are "
#    1911                     "supported through the usual rc parameter settings: "
#    1912                     "new century schoolbook, bookman, times, palatino, zapf chancery, "
#    1913                     "charter, serif, sans-serif, helvetica, avant garde, courier, "
#    1914                     "monospace, computer modern roman, computer modern sans serif, "
#    1915                     "computer modern typewriter"
#    1916     ),
#    1917     _Param(
#    1918         "text.latex.engine",
#    1919         default="latex",
#    1920         validator=["latex", "latex+dvipng"],
#    1921         description=(
#    1922             "The TeX engine/format to use.  The following values are supported:\n"
#    1923             "- 'latex': The classic TeX engine (the current default).  All backends "
#    1924             "render TeX's output by parsing the DVI output into glyphs and boxes and "
#    1925             "emitting those one by one.\n"
#    1926             "- 'latex+dvipng': The same as 'latex', with the exception that Agg-based "
#    1927             "backends rely on dvipng to rasterize TeX's output.  This value was the "
#    1928             "default up to Matplotlib 3.10."
#    1929         )
#    1930     ),
#    1931     _Param(
#    1932         "text.latex.preamble",
#    1933         default="",
#    1934         validator=validate_string,
#    1935         description='IMPROPER USE OF THIS FEATURE WILL LEAD TO LATEX FAILURES AND IS '
#    1936                     'THEREFORE UNSUPPORTED. PLEASE DO NOT ASK FOR HELP IF THIS FEATURE '
#    1937                     'DOES NOT DO WHAT YOU EXPECT IT TO. text.latex.preamble is a '
#    1938                     'single line of LaTeX code that will be passed on to the LaTeX '
#    1939                     'system. It may contain any code that is valid for the LaTeX '
#    1940                     '"preamble", i.e. between the "\\documentclass" and '
#    1941                     '"\\begin{document}" statements. Note that it has to be put on a '
#    1942                     'single line, which may become quite long. The following packages '
#    1943                     'are always loaded with usetex, so beware of package collisions: '
#    1944                     '   color, fix-cm, geometry, graphicx, textcomp. PostScript '
#    1945                     '(PSNFSS) font packages may also be loaded, depending on your font '
#    1946                     'settings.'
#    1947     ),
#    1948     _Param(
#    1949         "mathtext.fontset",
#    1950         default="dejavusans",
#    1951         validator=["dejavusans", "dejavuserif", "cm", "stix", "stixsans", "custom"],
#    1952         description="Should be 'dejavusans' (default), 'dejavuserif', "
#    1953                     "'cm' (Computer Modern), 'stix', 'stixsans' or 'custom'"
#    1954     ),
#    1955     _Param("mathtext.bf", "sans:bold", validate_font_properties),
#    1956     _Param("mathtext.bfit", "sans:italic:bold", validate_font_properties),
#    1957     _Param("mathtext.cal", "cursive", validate_font_properties),
#    1958     _Param("mathtext.it", "sans:italic", validate_font_properties),
#    1959     _Param("mathtext.rm", "sans", validate_font_properties),
#    1960     _Param("mathtext.sf", "sans", validate_font_properties),
#    1961     _Param("mathtext.tt", "monospace", validate_font_properties),
#    1962     _Param(
#    1963         "mathtext.fallback",
#    1964         default="cm",
#    1965         validator=_validate_mathtext_fallback,
#    1966         description="Select fallback font from ['cm' (Computer Modern), 'stix', "
#    1967                     "'stixsans'] when a symbol cannot be found in one of the custom "
#    1968                     "math fonts. Select 'None' to not perform fallback and replace the "
#    1969                     "missing character by a dummy symbol."
#    1970     ),
#    1971     _Param("mathtext.default", "normal",
#    1972            ["rm", "cal", "bfit", "it", "tt", "sf", "bf", "default", "bb", "frak", "scr",
#    1973             "regular", "normal"],
#    1974            description='The default font to use for math. Can be any of the LaTeX font '
#    1975                     'names, including the special name "regular" for the same font '
#    1976                     'used in regular text.',
#    1977            ),
#    1978     _Section("Axes"),
#    1979     _Param(
#    1980         "axes.facecolor",
#    1981         default="white",
#    1982         validator=validate_color,
#    1983         description="axes background color"
#    1984     ),
#    1985     _Param(
#    1986         "axes.edgecolor",
#    1987         default="black",
#    1988         validator=validate_color,
#    1989         description="axes edge color"
#    1990     ),
#    1991     _Param(
#    1992         "axes.linewidth",
#    1993         default=0.8,
#    1994         validator=validate_float,
#    1995         description="edge line width"
#    1996     ),
#    1997     _Param(
#    1998         "axes.grid",
#    1999         default=False,
#    2000         validator=validate_bool,
#    2001         description="display grid or not"
#    2002     ),
#    2003     _Param(
#    2004         "axes.grid.axis",
#    2005         default="both",
#    2006         validator=["x", "y", "both"],
#    2007         description="which axis the grid should apply to"
#    2008     ),
#    2009     _Param(
#    2010         "axes.grid.which",
#    2011         default="major",
#    2012         validator=["minor", "both", "major"],
#    2013         description="grid lines at {major, minor, both} ticks"
#    2014     ),
#    2015     _Param(
#    2016         "axes.titlelocation",
#    2017         default="center",
#    2018         validator=["left", "center", "right"],
#    2019         description="alignment of the title: {left, right, center}"
#    2020     ),
#    2021     _Param(
#    2022         "axes.titlesize",
#    2023         default="large",
#    2024         validator=validate_fontsize,
#    2025         description="font size of the axes title"
#    2026     ),
#    2027     _Param(
#    2028         "axes.titleweight",
#    2029         default="normal",
#    2030         validator=validate_fontweight,
#    2031         description="font weight of title"
#    2032     ),
#    2033     _Param(
#    2034         "axes.titlecolor",
#    2035         default="auto",
#    2036         validator=validate_color_or_auto,
#    2037         description="color of the axes title, auto falls back to text.color as default "
#    2038                     "value"
#    2039     ),
#    2040     _Param(
#    2041         "axes.titley",
#    2042         default=None,
#    2043         validator=validate_float_or_None,
#    2044         description="position title (axes relative units).  None implies auto"
#    2045     ),
#    2046     _Param(
#    2047         "axes.titlepad",
#    2048         default=6.0,
#    2049         validator=validate_float,
#    2050         description="pad between axes and title in points"
#    2051     ),
#    2052     _Param(
#    2053         "axes.labelsize",
#    2054         default="medium",
#    2055         validator=validate_fontsize,
#    2056         description="font size of the x and y labels"
#    2057     ),
#    2058     _Param(
#    2059         "axes.labelpad",
#    2060         default=4.0,
#    2061         validator=validate_float,
#    2062         description="space between label and axis"
#    2063     ),
#    2064     _Param(
#    2065         "axes.labelweight",
#    2066         default="normal",
#    2067         validator=validate_fontweight,
#    2068         description="weight of the x and y labels"
#    2069     ),
#    2070     _Param(
#    2071         "axes.labelcolor",
#    2072         default="black",
#    2073         validator=validate_color
#    2074     ),
#    2075     _Param(
#    2076         "axes.axisbelow",
#    2077         default="line",
#    2078         validator=validate_axisbelow,
#    2079         description="draw axis gridlines and ticks: "
#    2080                     "- below patches (True) "
#    2081                     "- above patches but below lines ('line') "
#    2082                     "- above all (False)"
#    2083     ),
#    2084     _Param(
#    2085         "axes.formatter.limits",
#    2086         default=[-5, 6],
#    2087         validator=validate_intlist,
#    2088         description="use scientific notation if log10 of the axis range is smaller "
#    2089                     "than the first or larger than the second"
#    2090     ),
#    2091     _Param(
#    2092         "axes.formatter.use_locale",
#    2093         default=False,
#    2094         validator=validate_bool,
#    2095         description="When True, format tick labels according to the user's locale. "
#    2096                     "For example, use ',' as a decimal separator in the fr_FR locale."
#    2097     ),
#    2098     _Param(
#    2099         "axes.formatter.use_mathtext",
#    2100         default=False,
#    2101         validator=validate_bool,
#    2102         description="When True, use mathtext for scientific notation."
#    2103     ),
#    2104     _Param(
#    2105         "axes.formatter.min_exponent",
#    2106         default=0,
#    2107         validator=validate_int,
#    2108         description="minimum exponent to format in scientific notation"
#    2109     ),
#    2110     _Param(
#    2111         "axes.formatter.useoffset",
#    2112         default=True,
#    2113         validator=validate_bool,
#    2114         description="If True, the tick label formatter will default to labeling ticks "
#    2115                     "relative to an offset when the data range is small compared to "
#    2116                     "the minimum absolute value of the data."
#    2117     ),
#    2118     _Param(
#    2119         "axes.formatter.offset_threshold",
#    2120         default=4,
#    2121         validator=validate_int,
#    2122         description="When useoffset is True, the offset will be used when it can "
#    2123                     "remove at least this number of significant digits from tick "
#    2124                     "labels."
#    2125     ),
#    2126     _Param(
#    2127         "axes.spines.left",
#    2128         default=True,
#    2129         validator=validate_bool,
#    2130         description="display axis spines"
#    2131     ),
#    2132     _Param("axes.spines.bottom", True, validate_bool),
#    2133     _Param("axes.spines.top", True, validate_bool),
#    2134     _Param(
#    2135         "axes.spines.right",
#    2136         default=True,
#    2137         validator=validate_bool
#    2138     ),
#    2139     _Param(
#    2140         "axes.unicode_minus",
#    2141         default=True,
#    2142         validator=validate_bool,
#    2143         description="use Unicode for the minus symbol rather than hyphen. See "
#    2144                     "https://en.wikipedia.org/wiki/Plus_and_minus_signs#Character_codes"
#    2145
#    2146     ),
#    2147     _Param("axes.prop_cycle",
# -> 2148         default=cycler(
#    2149             "color",
#    2150             [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#    2151              (1.0, 0.4980392156862745, 0.054901960784313725),
#    2152              (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#    2153              (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#    2154              (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#    2155              (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#    2156              (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#    2157              (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#    2158              (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#    2159              (0.09019607843137255, 0.7450980392156863, 0.8117647058823529),
#    2160             ],
#    2161         ),
#    2162         validator=validate_cycler
#    2163     ),
#    2164     _Param(
#    2165         "axes.xmargin",
#    2166         default=0.05,
#    2167         validator=_validate_greaterthan_minushalf,
#    2168         description="x margin.  See `~.axes.Axes.margins`"
#    2169     ),
#    2170     _Param(
#    2171         "axes.ymargin",
#    2172         default=0.05,
#    2173         validator=_validate_greaterthan_minushalf,
#    2174         description="y margin.  See `~.axes.Axes.margins`"
#    2175     ),
#    2176     _Param(
#    2177         "axes.zmargin",
#    2178         default=0.05,
#    2179         validator=_validate_greaterthan_minushalf,
#    2180         description="z margin.  See `~.axes.Axes.margins`"
#    2181     ),
#    2182     _Param(
#    2183         "axes.autolimit_mode",
#    2184         default="data",
#    2185         validator=["data", "round_numbers"],
#    2186         description='If "data", use axes.xmargin and axes.ymargin as is. If '
#    2187                     '"round_numbers", after application of margins, axis limits are '
#    2188                     'further expanded to the nearest "round" number.',
#    2189     ),
#    2190     _Subsection("Polar Axes"),
#    2191     _Param(
#    2192         "polaraxes.grid",
#    2193         default=True,
#    2194         validator=validate_bool,
#    2195         description="display grid on polar axes"
#    2196     ),
#    2197     _Subsection("3D Axes"),
#    2198     _Param(
#    2199         "axes3d.grid",
#    2200         default=True,
#    2201         validator=validate_bool, description="display grid on 3D axes"
#    2202     ),
#    2203     _Param(
#    2204         "axes3d.automargin",
#    2205         default=False,
#    2206         validator=validate_bool,
#    2207         description="automatically add margin when manually setting 3D axis limits"
#    2208     ),
#    2209     _Param(
#    2210         "axes3d.xaxis.panecolor",
#    2211         default=(0.95, 0.95, 0.95, 0.5),
#    2212         validator=validate_color,
#    2213         description="background pane on 3D axes"
#    2214     ),
#    2215     _Param(
#    2216         "axes3d.yaxis.panecolor",
#    2217         default=(0.9, 0.9, 0.9, 0.5),
#    2218         validator=validate_color,
#    2219         description="background pane on 3D axes"
#    2220     ),
#    2221     _Param(
#    2222         "axes3d.zaxis.panecolor",
#    2223         default=(0.925, 0.925, 0.925, 0.5),
#    2224         validator=validate_color,
#    2225         description="background pane on 3D axes"
#    2226     ),
#    2227     _Param(
#    2228         "axes3d.depthshade",
#    2229         default=True,
#    2230         validator=validate_bool,
#    2231         description="depth shade for 3D scatter plots"
#    2232     ),
#    2233     _Param(
#    2234         "axes3d.depthshade_minalpha",
#    2235         default=0.3,
#    2236         validator=validate_float,
#    2237         description="minimum alpha value for depth shading"
#    2238     ),
#    2239     _Param(
#    2240         "axes3d.mouserotationstyle",
#    2241         default="arcball",
#    2242         validator=["azel", "trackball", "sphere", "arcball"],
#    2243         description="{azel, trackball, sphere, arcball} See also "
#    2244                     "https://matplotlib.org/stable/api/toolkits/mplot3d/view_angles.html#rotation-with-mouse"),  # noqa
#    2245     _Param(
#    2246         "axes3d.trackballsize",
#    2247         default=0.667,
#    2248         validator=validate_float,
#    2249         description="trackball diameter, in units of the Axes bbox"
#    2250     ),
#    2251     _Param(
#    2252         "axes3d.trackballborder",
#    2253         default=0.2,
#    2254         validator=validate_float,
#    2255         description="trackball border width, in units of the Axes bbox (only for "
#    2256                     "'sphere' and 'arcball' style)"
#    2257     ),
#    2258     _Section("Axis"),
#    2259     _Param(
#    2260         "axes3d.snap_rotation",
#    2261         default=5.0,
#    2262         validator=validate_float,
#    2263         description="Snap angle (in degrees) for 3D rotation when holding Control."
#    2264    ),
#    2265     _Param(
#    2266         "xaxis.labellocation",
#    2267         default="center",
#    2268         validator=["left", "center", "right"],
#    2269         description="alignment of the xaxis label: {left, right, center}"
#    2270     ),
#    2271     _Param(
#    2272         "yaxis.labellocation",
#    2273         default="center",
#    2274         validator=["bottom", "center", "top"],
#    2275         description="alignment of the yaxis label: {bottom, top, center}"
#    2276     ),
#    2277     _Section(
#    2278         "Dates",
#    2279         description="Default properties for date tick labels. These are used by the "
#    2280                     "`.AutoDateFormatter` when the appropriate time unit is detected."
#    2281                     "See "
#    2282                     "https://matplotlib.org/stable/api/dates_api.html#date-formatters "
#    2283                     "for more information."
#    2284     ),
#    2285     _Param("date.autoformatter.year", "%Y", validate_string),
#    2286     _Param("date.autoformatter.month", "%Y-%m", validate_string),
#    2287     _Param("date.autoformatter.day", "%Y-%m-%d", validate_string),
#    2288     _Param("date.autoformatter.hour", "%m-%d %H", validate_string),
#    2289     _Param("date.autoformatter.minute", "%d %H:%M", validate_string),
#    2290     _Param("date.autoformatter.second", "%H:%M:%S", validate_string),
#    2291     _Param("date.autoformatter.microsecond", "%M:%S.%f", validate_string),
#    2292     _Param(
#    2293         "date.epoch",
#    2294         default="1970-01-01T00:00:00",
#    2295         validator=_validate_date,
#    2296         description="The reference date for Matplotlib's internal date representation. "
#    2297                     "See https://matplotlib.org/stable/gallery/ticks/date_precision_and_epochs.html"),  #noqa
#    2298     _Param(
#    2299         "date.converter",
#    2300         default="auto",
#    2301         validator=["auto", "concise"],
#    2302         description="'auto', 'concise'"
#    2303     ),
#    2304     _Param(
#    2305         "date.interval_multiples",
#    2306         default=True,
#    2307         validator=validate_bool,
#    2308         description="For auto converter whether to use interval_multiples"
#    2309     ),
#    2310     _Section("Ticks"),
#    2311     _Param(
#    2312         "xtick.top",
#    2313         default=False,
#    2314         validator=validate_bool,
#    2315         description="draw ticks on the top side"
#    2316     ),
#    2317     _Param(
#    2318         "xtick.bottom",
#    2319         default=True,
#    2320         validator=validate_bool,
#    2321         description="draw ticks on the bottom side"
#    2322     ),
#    2323     _Param(
#    2324         "xtick.labeltop",
#    2325         default=False,
#    2326         validator=validate_bool,
#    2327         description="draw label on the top"
#    2328     ),
#    2329     _Param(
#    2330         "xtick.labelbottom",
#    2331         default=True,
#    2332         validator=validate_bool,
#    2333         description="draw label on the bottom"
#    2334     ),
#    2335     _Param(
#    2336         "xtick.major.size",
#    2337         default=3.5,
#    2338         validator=validate_float,
#    2339         description="major tick size in points"
#    2340     ),
#    2341     _Param(
#    2342         "xtick.minor.size",
#    2343         default=2.0,
#    2344         validator=validate_float,
#    2345         description="minor tick size in points"
#    2346     ),
#    2347     _Param(
#    2348         "xtick.major.width",
#    2349         default=0.8,
#    2350         validator=validate_float,
#    2351         description="major tick width in points"
#    2352     ),
#    2353     _Param(
#    2354         "xtick.minor.width",
#    2355         default=0.6,
#    2356         validator=validate_float,
#    2357         description="minor tick width in points"
#    2358     ),
#    2359     _Param(
#    2360         "xtick.major.pad",
#    2361         default=3.5,
#    2362         validator=validate_float,
#    2363         description="distance to major tick label in points"
#    2364     ),
#    2365     _Param(
#    2366         "xtick.minor.pad",
#    2367         default=3.4,
#    2368         validator=validate_float,
#    2369         description="distance to the minor tick label in points"
#    2370     ),
#    2371     _Param(
#    2372         "xtick.color",
#    2373         default="black",
#    2374         validator=validate_color,
#    2375         description="color of the ticks"
#    2376     ),
#    2377     _Param(
#    2378         "xtick.labelcolor",
#    2379         default="inherit",
#    2380         validator=validate_color_or_inherit,
#    2381         description="color of the tick labels or inherit from xtick.color"
#    2382     ),
#    2383     _Param(
#    2384         "xtick.labelsize",
#    2385         default="medium",
#    2386         validator=validate_fontsize,
#    2387         description="font size of the tick labels"
#    2388     ),
#    2389     _Param(
#    2390         "xtick.direction",
#    2391         default="out",
#    2392         validator=["out", "in", "inout"],
#    2393         description="direction: {in, out, inout}"
#    2394     ),
#    2395     _Param(
#    2396         "xtick.minor.visible",
#    2397         default=False,
#    2398         validator=validate_bool,
#    2399         description="visibility of minor ticks on x-axis"
#    2400     ),
#    2401     _Param(
#    2402         "xtick.major.top",
#    2403         default=True,
#    2404         validator=validate_bool,
#    2405         description="draw x axis top major ticks"
#    2406     ),
#    2407     _Param(
#    2408         "xtick.major.bottom",
#    2409         default=True,
#    2410         validator=validate_bool,
#    2411         description="draw x axis bottom major ticks"
#    2412     ),
#    2413     _Param(
#    2414         "xtick.minor.top",
#    2415         default=True,
#    2416         validator=validate_bool,
#    2417         description="draw x axis top minor ticks"
#    2418     ),
#    2419     _Param(
#    2420         "xtick.minor.bottom",
#    2421         default=True,
#    2422         validator=validate_bool,
#    2423         description="draw x axis bottom minor ticks"
#    2424     ),
#    2425     _Param(
#    2426         "xtick.minor.ndivs",
#    2427         default="auto",
#    2428         validator=_validate_minor_tick_ndivs,
#    2429         description="number of minor ticks between the major ticks on x-axis"
#    2430     ),
#    2431     _Param(
#    2432         "xtick.alignment",
#    2433         default="center",
#    2434         validator=["center", "right", "left"],
#    2435         description="alignment of xticks"
#    2436     ),
#    2437     _Param(
#    2438         "ytick.left",
#    2439         default=True,
#    2440         validator=validate_bool,
#    2441         description="draw ticks on the left side"
#    2442     ),
#    2443     _Param(
#    2444         "ytick.right",
#    2445         default=False,
#    2446         validator=validate_bool,
#    2447         description="draw ticks on the right side"
#    2448     ),
#    2449     _Param(
#    2450         "ytick.labelleft",
#    2451         default=True,
#    2452         validator=validate_bool,
#    2453         description="draw tick labels on the left side"
#    2454     ),
#    2455     _Param(
#    2456         "ytick.labelright",
#    2457         default=False,
#    2458         validator=validate_bool,
#    2459         description="draw tick labels on the right side"
#    2460     ),
#    2461     _Param(
#    2462         "ytick.major.size",
#    2463         default=3.5,
#    2464         validator=validate_float,
#    2465         description="major tick size in points"
#    2466     ),
#    2467     _Param(
#    2468         "ytick.minor.size",
#    2469         default=2.0,
#    2470         validator=validate_float,
#    2471         description="minor tick size in points"
#    2472     ),
#    2473     _Param(
#    2474         "ytick.major.width",
#    2475         default=0.8,
#    2476         validator=validate_float,
#    2477         description="major tick width in points"
#    2478     ),
#    2479     _Param(
#    2480         "ytick.minor.width",
#    2481         default=0.6,
#    2482         validator=validate_float,
#    2483         description="minor tick width in points"
#    2484     ),
#    2485     _Param(
#    2486         "ytick.major.pad",
#    2487         default=3.5,
#    2488         validator=validate_float,
#    2489         description="distance to major tick label in points"
#    2490     ),
#    2491     _Param(
#    2492         "ytick.minor.pad",
#    2493         default=3.4,
#    2494         validator=validate_float,
#    2495         description="distance to the minor tick label in points"
#    2496     ),
#    2497     _Param(
#    2498         "ytick.color",
#    2499         default="black",
#    2500         validator=validate_color,
#    2501         description="color of the ticks"
#    2502     ),
#    2503     _Param(
#    2504         "ytick.labelcolor",
#    2505         default="inherit",
#    2506         validator=validate_color_or_inherit,
#    2507         description="color of the tick labels or inherit from ytick.color"
#    2508     ),
#    2509     _Param(
#    2510         "ytick.labelsize",
#    2511         default="medium",
#    2512         validator=validate_fontsize,
#    2513         description="font size of the tick labels"
#    2514     ),
#    2515     _Param(
#    2516         "ytick.direction",
#    2517         default="out",
#    2518         validator=["out", "in", "inout"],
#    2519         description="direction: {in, out, inout}"
#    2520     ),
#    2521     _Param(
#    2522         "ytick.minor.visible",
#    2523         default=False,
#    2524         validator=validate_bool,
#    2525         description="visibility of minor ticks on y-axis"
#    2526     ),
#    2527     _Param(
#    2528         "ytick.major.left",
#    2529         default=True,
#    2530         validator=validate_bool,
#    2531         description="draw y axis left major ticks"
#    2532     ),
#    2533     _Param(
#    2534         "ytick.major.right",
#    2535         default=True,
#    2536         validator=validate_bool,
#    2537         description="draw y axis right major ticks"
#    2538     ),
#    2539     _Param(
#    2540         "ytick.minor.left",
#    2541         default=True,
#    2542         validator=validate_bool,
#    2543         description="draw y axis left minor ticks"
#    2544     ),
#    2545     _Param(
#    2546         "ytick.minor.right",
#    2547         default=True,
#    2548         validator=validate_bool,
#    2549         description="draw y axis right minor ticks"
#    2550     ),
#    2551     _Param(
#    2552         "ytick.minor.ndivs",
#    2553         default="auto",
#    2554         validator=_validate_minor_tick_ndivs,
#    2555         description="number of minor ticks between the major ticks on y-axis"
#    2556     ),
#    2557     _Param("ytick.alignment", "center_baseline",
#    2558            ["center", "top", "bottom", "baseline", "center_baseline"],
#    2559            description="alignment of yticks"
#    2560            ),
#    2561     _Section("Grid"),
#    2562     _Param(
#    2563         "grid.color",
#    2564         default="#b0b0b0",
#    2565         validator=validate_color,
#    2566         description='b0b0b0"  # grid color'
#    2567     ),
#    2568     _Param(
#    2569         "grid.linestyle",
#    2570         default="-",
#    2571         validator=_validate_linestyle,
#    2572         description="solid"
#    2573     ),
#    2574     _Param(
#    2575         "grid.linewidth",
#    2576         default=0.8,
#    2577         validator=validate_float,
#    2578         description="in points"
#    2579     ),
#    2580     _Param(
#    2581         "grid.alpha",
#    2582         default=1.0,
#    2583         validator=validate_float,
#    2584         description="transparency, between 0.0 and 1.0"
#    2585     ),
#    2586     _Param(
#    2587         "grid.major.color",
#    2588         default=None,
#    2589         validator=_validate_color_or_None,
#    2590         description="If None defaults to grid.color"
#    2591     ),
#    2592     _Param(
#    2593         "grid.major.linestyle",
#    2594         default=None,
#    2595         validator=_validate_linestyle_or_None,
#    2596         description="If None defaults to grid.linestyle"
#    2597     ),
#    2598     _Param(
#    2599         "grid.major.linewidth",
#    2600         default=None,
#    2601         validator=validate_float_or_None,
#    2602         description="If None defaults to grid.linewidth"
#    2603     ),
#    2604     _Param(
#    2605         "grid.major.alpha",
#    2606         default=None,
#    2607         validator=validate_float_or_None,
#    2608         description="If None defaults to grid.alpha"
#    2609     ),
#    2610     _Param(
#    2611         "grid.minor.color",
#    2612         default=None,
#    2613         validator=_validate_color_or_None,
#    2614         description="If None defaults to grid.color"
#    2615     ),
#    2616     _Param(
#    2617         "grid.minor.linestyle",
#    2618         default=None,
#    2619         validator=_validate_linestyle_or_None,
#    2620         description="If None defaults to grid.linestyle"
#    2621     ),
#    2622     _Param(
#    2623         "grid.minor.linewidth",
#    2624         default=None,
#    2625         validator=validate_float_or_None,
#    2626         description="If None defaults to grid.linewidth"
#    2627     ),
#    2628     _Param(
#    2629         "grid.minor.alpha",
#    2630         default=None,
#    2631         validator=validate_float_or_None,
#    2632         description="If None defaults to grid.alpha"
#    2633     ),
#    2634     _Section("Legend"),
#    2635     _Param(
#    2636         "legend.loc",
# ...
#    3187         default=6,
#    3188         validator=validate_int,
#    3189         description="integer from 0 to 9 0 disables compression (good for debugging)"
#    3190     ),
#    3191     _Param(
#    3192         "pdf.fonttype",
#    3193         default=3,
#    3194         validator=validate_fonttype,
#    3195         description="Output Type 3 (Type3) or Type 42 (TrueType)"
#    3196     ),
#    3197     _Param(
#    3198         "pdf.use14corefonts",
#    3199         default=False,
#    3200         validator=validate_bool
#    3201     ),
#    3202     _Param(
#    3203         "pdf.inheritcolor",
#    3204         default=False,
#    3205         validator=validate_bool
#    3206     ),
#    3207     _Subsection("SVG backend parameters"),
#    3208     _Param(
#    3209         "svg.image_inline",
#    3210         default=True,
#    3211         validator=validate_bool,
#    3212         description="Write raster image data directly into the SVG file"
#    3213     ),
#    3214     _Param(
#    3215         "svg.fonttype",
#    3216         default="path",
#    3217         validator=["none", "path"],
#    3218         description="How to handle SVG fonts: "
#    3219                     "path: Embed characters as paths -- supported by most SVG "
#    3220                     "      renderers"
#    3221                     "none: Assume fonts are installed on the machine where the SVG "
#    3222                     "will be viewed."
#    3223     ),
#    3224     _Param(
#    3225         "svg.hashsalt",
#    3226         default=None,
#    3227         validator=validate_string_or_None,
#    3228         description="If not None, use this string as hash salt instead of uuid4"
#    3229     ),
#    3230     _Param(
#    3231         "svg.id",
#    3232         default=None,
#    3233         validator=validate_string_or_None,
#    3234         description="If not None, use this string as the value for the `id` attribute "
#    3235                     "in the top <svg> tag"
#    3236     ),
#    3237     _Subsection("PGF parameters"),
#    3238     _Param(
#    3239         "pgf.rcfonts",
#    3240         default=True,
#    3241         validator=validate_bool
#    3242     ),
#    3243     _Param(
#    3244         "pgf.preamble",
#    3245         default="",
#    3246         validator=validate_string,
#    3247         description="See text.latex.preamble for documentation"
#    3248     ),
#    3249     _Param(
#    3250         "pgf.texsystem",
#    3251         default="xelatex",
#    3252         validator=["xelatex", "lualatex", "pdflatex"]
#    3253     ),
#    3254     _Subsection("Docstring parameters"),
#    3255     _Param(
#    3256         "docstring.hardcopy",
#    3257         default=False,
#    3258         validator=validate_bool,
#    3259         description="set this when you want to generate hardcopy docstring"
#    3260     ),
#    3261     _Section(
#    3262         "Interactive keymaps",
#    3263         description="Default key mappings for interactive navigation. See "
#    3264                     ":ref:`key-event-handling`."
#    3265     ),
#    3266     _Param(
#    3267         "keymap.fullscreen",
#    3268         default=["f", "ctrl+f"],
#    3269         validator=validate_stringlist,
#    3270         description="toggling"
#    3271     ),
#    3272     _Param(
#    3273         "keymap.home",
#    3274         default=["h", "r", "home"],
#    3275         validator=validate_stringlist,
#    3276         description="home or reset mnemonic"
#    3277     ),
#    3278     _Param(
#    3279         "keymap.back",
#    3280         default=["left", "c", "backspace", "MouseButton.BACK"],
#    3281         validator=validate_stringlist, description="forward / backward keys"
#    3282     ),
#    3283     _Param(
#    3284         "keymap.forward",
#    3285         default=["right", "v", "MouseButton.FORWARD"],
#    3286         validator=validate_stringlist,
#    3287         description="for quick navigation"
#    3288     ),
#    3289     _Param(
#    3290         "keymap.pan",
#    3291         default=["p"],
#    3292         validator=validate_stringlist, description="pan mnemonic"
#    3293     ),
#    3294     _Param(
#    3295         "keymap.zoom",
#    3296         default=["o"],
#    3297         validator=validate_stringlist, description="zoom mnemonic"
#    3298     ),
#    3299     _Param(
#    3300         "keymap.save",
#    3301         default=["s", "ctrl+s"],
#    3302         validator=validate_stringlist,
#    3303         description="saving current figure"
#    3304     ),
#    3305     _Param(
#    3306         "keymap.help",
#    3307         default=["f1"],
#    3308         validator=validate_stringlist,
#    3309         description="display help about active tools"
#    3310     ),
#    3311     _Param(
#    3312         "keymap.quit",
#    3313         default=["ctrl+w", "cmd+w", "q"],
#    3314         validator=validate_stringlist,
#    3315         description="close the current figure"
#    3316     ),
#    3317     _Param(
#    3318         "keymap.quit_all",
#    3319         default=[],
#    3320         validator=validate_stringlist, description="close all figures"
#    3321     ),
#    3322     _Param(
#    3323         "keymap.grid",
#    3324         default=["g"],
#    3325         validator=validate_stringlist,
#    3326         description="switching on/off major grids in current axes"
#    3327     ),
#    3328     _Param(
#    3329         "keymap.grid_minor",
#    3330         default=["G"],
#    3331         validator=validate_stringlist,
#    3332         description="switching on/off minor grids in current axes"
#    3333     ),
#    3334     _Param(
#    3335         "keymap.yscale",
#    3336         default=["l"],
#    3337         validator=validate_stringlist,
#    3338         description="toggle scaling of y-axes ('log'/'linear')"
#    3339     ),
#    3340     _Param(
#    3341         "keymap.xscale",
#    3342         default=["k", "L"],
#    3343         validator=validate_stringlist,
#    3344         description="toggle scaling of x-axes ('log'/'linear')"
#    3345     ),
#    3346     _Param(
#    3347         "keymap.copy",
#    3348         default=["ctrl+c", "cmd+c"],
#    3349         validator=validate_stringlist,
#    3350         description="copy figure to clipboard"
#    3351     ),
#    3352     _Section("Animation"),
#    3353     _Param(
#    3354         "animation.html",
#    3355         default="none",
#    3356         validator=["html5", "jshtml", "none"],
#    3357         description="How to display the animation as HTML in the IPython notebook: "
#    3358                     "- 'html5' uses HTML5 video tag "
#    3359                     "- 'jshtml' creates a JavaScript animation"
#    3360     ),
#    3361     _Param(
#    3362         "animation.writer",
#    3363         default="ffmpeg",
#    3364         validator=validate_string,
#    3365         description="MovieWriter 'backend' to use"
#    3366     ),
#    3367     _Param(
#    3368         "animation.codec",
#    3369         default="h264",
#    3370         validator=validate_string,
#    3371         description="Codec to use for writing movie"
#    3372     ),
#    3373     _Param(
#    3374         "animation.bitrate",
#    3375         default=-1,
#    3376         validator=validate_int,
#    3377         description="Controls size/quality trade-off for movie. -1 implies let "
#    3378                     "utility auto-determine"
#    3379     ),
#    3380     _Param("animation.frame_format", "png",
#    3381            ["png", "jpeg", "tiff", "raw", "rgba", "ppm", "sgi", "bmp", "pbm", "svg"],
#    3382            description="Controls frame format used by temp files"
#    3383            ),
#    3384     _Param(
#    3385         "animation.ffmpeg_path",
#    3386         default="ffmpeg",
#    3387         validator=_validate_pathlike,
#    3388         description="Path to ffmpeg binary.  Unqualified paths are resolved by "
#    3389                     "subprocess.Popen."
#    3390     ),
#    3391     _Param(
#    3392         "animation.ffmpeg_args",
#    3393         default=[],
#    3394         validator=validate_stringlist,
#    3395         description="Additional arguments to pass to ffmpeg"
#    3396     ),
#    3397     _Param(
#    3398         "animation.convert_path",
#    3399         default="convert",
#    3400         validator=_validate_pathlike,
#    3401         description="Path to ImageMagick's convert binary.  Unqualified paths are "
#    3402                     "resolved by subprocess.Popen, except that on Windows, we look up "
#    3403                     "an install of ImageMagick in the registry (as convert is also the "
#    3404                     "name of a system tool)."
#    3405     ),
#    3406     _Param(
#    3407         "animation.convert_args",
#    3408         default=["-layers", "OptimizePlus"],
#    3409         validator=validate_stringlist,
#    3410         description="Additional arguments to pass to convert"
#    3411     ),
#    3412     _Param(
#    3413         "animation.embed_limit",
#    3414         default=20.0,
#    3415         validator=validate_float,
#    3416         description="Limit, in MB, of size of base64 encoded animation in HTML (i.e. "
#    3417                     "IPython notebook)"
#    3418     ),
#    3419     _Param(
#    3420         "_internal.classic_mode",
#    3421         default=False,
#    3422         validator=validate_bool
#    3423     ),
#    3424     _Param("backend", None, validate_backend),
#    3425 ]
#    3428 def _params_list():
#    3429     return [elem for elem in _DEFINITION if isinstance(elem, _Param)]
#
# File ~/BitsPilani/2nd Year/AIMLCZG520_SpeechProcessing/Assignment/Solution/SpeechProcessing/.venv/lib/python3.11/site-packages/matplotlib/rcsetup.py:810, in cycler(*args, **kwargs)
#     808 if validator is None:
#     809     raise TypeError("Unknown artist property: %s" % prop)
# --> 810 vals = validator(vals)
#     811 # We will normalize the property names as well to reduce
#     812 # the amount of alias handling code elsewhere.
#     813 validated.append((norm_prop, vals))
#
# File ~/BitsPilani/2nd Year/AIMLCZG520_SpeechProcessing/Assignment/Solution/SpeechProcessing/.venv/lib/python3.11/site-packages/matplotlib/rcsetup.py:146, in _listify_validator.<locals>.f(s)
#     139 # Allow any ordered sequence type -- generators, np.ndarray, pd.Series
#     140 # -- but not sets, whose iteration order is non-deterministic.
#     141 elif np.iterable(s) and not isinstance(s, (set, frozenset)):
#     142     # The condition on this list comprehension will preserve the
#     143     # behavior of filtering out any empty strings (behavior was
#     144     # from the original validate_stringlist()), while allowing
#     145     # any non-string/text scalar values such as numbers and arrays.
# --> 146     val = [scalar_validator(v) for v in s
#     147            if not isinstance(v, str) or v]
#     148 else:
#     149     raise ValueError(
#     150         f"Expected str or other non-set iterable, but got {s}")
#
# File ~/BitsPilani/2nd Year/AIMLCZG520_SpeechProcessing/Assignment/Solution/SpeechProcessing/.venv/lib/python3.11/site-packages/matplotlib/rcsetup.py:146, in <listcomp>(.0)
#     139 # Allow any ordered sequence type -- generators, np.ndarray, pd.Series
#     140 # -- but not sets, whose iteration order is non-deterministic.
#     141 elif np.iterable(s) and not isinstance(s, (set, frozenset)):
#     142     # The condition on this list comprehension will preserve the
#     143     # behavior of filtering out any empty strings (behavior was
#     144     # from the original validate_stringlist()), while allowing
#     145     # any non-string/text scalar values such as numbers and arrays.
# --> 146     val = [scalar_validator(v) for v in s
#     147            if not isinstance(v, str) or v]
#     148 else:
#     149     raise ValueError(
#     150         f"Expected str or other non-set iterable, but got {s}")
#
# File ~/BitsPilani/2nd Year/AIMLCZG520_SpeechProcessing/Assignment/Solution/SpeechProcessing/.venv/lib/python3.11/site-packages/matplotlib/rcsetup.py:351, in validate_color_for_prop_cycle(s)
#     349 if isinstance(s, str) and re.match("^C[0-9]$", s):
#     350     raise ValueError(f"Cannot put cycle reference ({s!r}) in prop_cycler")
# --> 351 return validate_color(s)
#
# File ~/BitsPilani/2nd Year/AIMLCZG520_SpeechProcessing/Assignment/Solution/SpeechProcessing/.venv/lib/python3.11/site-packages/matplotlib/rcsetup.py:385, in validate_color(s)
#     382         if is_color_like(stmp):
#     383             return stmp
# --> 385 if is_color_like(s):
#     386     return s
#     388 # If it is still valid, it must be a tuple (as a string from matplotlibrc).
#
# File ~/BitsPilani/2nd Year/AIMLCZG520_SpeechProcessing/Assignment/Solution/SpeechProcessing/.venv/lib/python3.11/site-packages/matplotlib/colors.py:232, in is_color_like(c)
#     230     return True
#     231 try:
# --> 232     to_rgba(c)
#     233 except (TypeError, ValueError):
#     234     return False
#
# File ~/BitsPilani/2nd Year/AIMLCZG520_SpeechProcessing/Assignment/Solution/SpeechProcessing/.venv/lib/python3.11/site-packages/matplotlib/colors.py:345, in to_rgba(c, alpha)
#     343     rgba = None
#     344 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 345     rgba = _to_rgba_no_colorcycle(c, alpha)
#     346     try:
#     347         _colors_full_map.cache[c, alpha] = rgba
#
# File ~/BitsPilani/2nd Year/AIMLCZG520_SpeechProcessing/Assignment/Solution/SpeechProcessing/.venv/lib/python3.11/site-packages/matplotlib/colors.py:367, in _to_rgba_no_colorcycle(c, alpha)
#     365     raise ValueError("'alpha' must be between 0 and 1, inclusive")
#     366 orig_c = c
# --> 367 if c is np.ma.masked:
#     368     return (0., 0., 0., 0.)
#     369 if isinstance(c, str):
#
# File ~/BitsPilani/2nd Year/AIMLCZG520_SpeechProcessing/Assignment/Solution/SpeechProcessing/.venv/lib/python3.11/site-packages/numpy/__init__.py:724, in __getattr__(attr)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/BitsPilani/2nd Year/AIMLCZG520_SpeechProcessing/Assignment/Solution/SpeechProcessing/.venv/lib/python3.11/site-packages/numpy/ma/__init__.py:42
#       1 """
#       2 =============
#       3 Masked Arrays
#    (...)     40
#      41 """
# ---> 42 from . import core
#      43 from .core import *
#      45 from . import extras
#
# File ~/BitsPilani/2nd Year/AIMLCZG520_SpeechProcessing/Assignment/Solution/SpeechProcessing/.venv/lib/python3.11/site-packages/numpy/ma/core.py:37
#      35 from numpy import ndarray, amax, amin, iscomplexobj, bool_, _NoValue
#      36 from numpy import array as narray
# ---> 37 from numpy.lib.function_base import angle
#      38 from numpy.compat import (
#      39     getargspec, formatargspec, long, unicode, bytes
#      40     )
#      41 from numpy import expand_dims
#
# File ~/BitsPilani/2nd Year/AIMLCZG520_SpeechProcessing/Assignment/Solution/SpeechProcessing/.venv/lib/python3.11/site-packages/numpy/lib/function_base.py:25
#      23 from numpy.core import overrides
#      24 from numpy.core.function_base import add_newdoc
# ---> 25 from numpy.lib.twodim_base import diag
#      26 from numpy.core.multiarray import (
#      27     _place, add_docstring, bincount, normalize_axis_index, _monotonicity,
#      28     interp as compiled_interp, interp_complex as compiled_interp_complex
#      29     )
#      30 from numpy.core.umath import _add_newdoc_ufunc as add_newdoc_ufunc
#
# File ~/BitsPilani/2nd Year/AIMLCZG520_SpeechProcessing/Assignment/Solution/SpeechProcessing/.venv/lib/python3.11/site-packages/numpy/lib/twodim_base.py:15
#      13 from numpy.core import overrides
#      14 from numpy.core import iinfo
# ---> 15 from numpy.lib.stride_tricks import broadcast_to
#      18 __all__ = [
#      19     'diag', 'diagflat', 'eye', 'fliplr', 'flipud', 'tri', 'triu',
#      20     'tril', 'vander', 'histogram2d', 'mask_indices', 'tril_indices',
#      21     'tril_indices_from', 'triu_indices', 'triu_indices_from', ]
#      24 array_function_dispatch = functools.partial(
#      25     overrides.array_function_dispatch, module='numpy')
#
# ImportError: cannot import name 'broadcast_to' from 'numpy.lib.stride_tricks' (/Users/pavankumararepu/BitsPilani/2nd Year/AIMLCZG520_SpeechProcessing/Assignment/Solution/SpeechProcessing/.venv/lib/python3.11/site-packages/numpy/lib/stride_tricks.py)
